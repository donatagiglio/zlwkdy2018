# %%
#!/usr/bin/env python

import zillow
import pprint
import zipcode

# %%
if __name__=="__main__":
    key = ""
    with open("/Users/giglio/Desktop/ACC_JISAO/code/zillow_us/zillow_env/bin/config/zillow_key.conf", 'r') as f:
        key = f.readline().replace("\n", "")

    address = "3400 Pacific Ave., Marina Del Rey, CA"
    postal_code = "90292"

    api = zillow.ValuationApi()
    data = api.GetSearchResults(key, address, postal_code)

    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(data.get_dict())

    detail_data = api.GetZEstimate(key, data.zpid)

    comp_data = api.GetComps(key, data.zpid)

    pp.pprint(comp_data['comps'][1].get_dict())

    deep_results = api.GetDeepSearchResults(key, "1920 1st Street South Apt 407, Minneapolis, MN", "55454")
    pp.pprint(deep_results.get_dict())
# Out:
# {   'extended_data': {   'bathrooms': None,
#                          'bedrooms': None,
#                          'complete': False,
#                          'finished_sqft': None,
#                          'fips_county': None,
#                          'last_sold_date': None,
#                          'last_sold_price': None,
#                          'lot_size_sqft': None,
#                          'tax_assessment': None,
#                          'tax_assessment_year': None,
#                          'usecode': None,
#                          'year_built': None},
#     'full_address': {   'city': 'Marina Del Rey',
#                         'latitude': '33.9781',
#                         'longitude': '-118.4643',
#                         'state': 'CA',
#                         'street': '3400 Pacific Ave APT 201',
#                         'zipcode': '90292'},
#     'links': {   'comparables': 'http://www.zillow.com/homes/comps/2100641621_zpid/',
#                  'graphs_and_data': None,
#                  'home_details': 'https://www.zillow.com/homedetails/3400-Pacific-Ave-APT-201-Marina-Del-Rey-CA--292/2100641621_zpid/',
#                  'map_this_home': 'http://www.zillow.com/homes/2100641621_zpid/'},
#     'local_realestate': {   'fsbo_link': 'http://www.zillow.com/venice-los-angeles-ca/fsbo/',
#                             'overview_link': 'http://www.zillow.com/local-info/CA-Los-Angeles/Venice/r_21056/',
#                             'region_id': '21056',
#                             'region_name': 'Venice',
#                             'region_type': 'neighborhood',
#                             'sale_link': 'http://www.zillow.com/venice-los-angeles-ca/',
#                             'zillow_home_value_index': None},
#     'similarity_score': None,
#     'zestimate': {   'amount': 2775632,
#                      'amount_change_30days': 67276,
#                      'amount_currency': 'USD',
#                      'amount_last_updated': '07/10/2018',
#                      'valuation_range_high': 3719347,
#                      'valuation_range_low': 1915186},
#     'zpid': '2100641621'}
# {   'extended_data': {   'bathrooms': None,
#                          'bedrooms': None,
#                          'complete': False,
#                          'finished_sqft': None,
#                          'fips_county': None,
#                          'last_sold_date': None,
#                          'last_sold_price': None,
#                          'lot_size_sqft': None,
#                          'tax_assessment': None,
#                          'tax_assessment_year': None,
#                          'usecode': None,
#                          'year_built': None},
#     'full_address': {   'city': 'Santa Monica',
#                         'latitude': '34.011057',
#                         'longitude': '-118.482553',
#                         'state': 'CA',
#                         'street': '714 Bay St APT 1',
#                         'zipcode': '90405'},
#     'links': {   'comparables': 'http://www.zillow.com/homes/comps/2093854611_zpid/',
#                  'graphs_and_data': None,
#                  'home_details': 'https://www.zillow.com/homedetails/714-Bay-St-APT-1-Santa-Monica-CA--405/2093854611_zpid/',
#                  'map_this_home': 'http://www.zillow.com/homes/2093854611_zpid/'},
#     'local_realestate': {   'fsbo_link': 'http://www.zillow.com/ocean-park-santa-monica-ca/fsbo/',
#                             'overview_link': 'http://www.zillow.com/local-info/CA-Santa-Monica/Ocean-Park/r_117023/',
#                             'region_id': '117023',
#                             'region_name': 'Ocean Park',
#                             'region_type': 'neighborhood',
#                             'sale_link': 'http://www.zillow.com/ocean-park-santa-monica-ca/',
#                             'zillow_home_value_index': None},
#     'similarity_score': '17.0',
#     'zestimate': {   'amount': 2176337,
#                      'amount_change_30days': -128560,
#                      'amount_currency': 'USD',
#                      'amount_last_updated': '07/10/2018',
#                      'valuation_range_high': 2916292,
#                      'valuation_range_low': 1479909},
#     'zpid': '2093854611'}
# {   'extended_data': {   'bathrooms': '1.0',
#                          'bedrooms': '1',
#                          'complete': True,
#                          'finished_sqft': '596',
#                          'fips_county': '27053',
#                          'last_sold_date': '10/19/2005',
#                          'last_sold_price': '121926',
#                          'lot_size_sqft': '680',
#                          'tax_assessment': '98500.0',
#                          'tax_assessment_year': '2017',
#                          'usecode': 'Condominium',
#                          'year_built': '1973'},
#     'full_address': {   'city': 'MINNEAPOLIS',
#                         'latitude': '44.975855',
#                         'longitude': '-93.244747',
#                         'state': 'MN',
#                         'street': '1920 S 1st St APT 407',
#                         'zipcode': '55454'},
#     'links': {   'comparables': 'http://www.zillow.com/homes/comps/1927741_zpid/',
#                  'graphs_and_data': 'http://www.zillow.com/homedetails/1920-S-1st-St-APT-407-Minneapolis-MN-55454/1927741_zpid/#charts-and-data',
#                  'home_details': 'https://www.zillow.com/homedetails/1920-S-1st-St-APT-407-Minneapolis-MN-55454/1927741_zpid/',
#                  'map_this_home': 'http://www.zillow.com/homes/1927741_zpid/'},
#     'local_realestate': {   'fsbo_link': 'http://www.zillow.com/cedar-riverside-minneapolis-mn/fsbo/',
#                             'overview_link': 'http://www.zillow.com/local-info/MN-Minneapolis/Cedar--Riverside/r_270096/',
#                             'region_id': '270096',
#                             'region_name': 'Cedar-Riverside',
#                             'region_type': 'neighborhood',
#                             'sale_link': 'http://www.zillow.com/cedar-riverside-minneapolis-mn/',
#                             'zillow_home_value_index': None},
#     'similarity_score': None,
#     'zestimate': {   'amount': 121903,
#                      'amount_change_30days': 654,
#                      'amount_currency': 'USD',
#                      'amount_last_updated': '07/10/2018',
#                      'valuation_range_high': 129217,
#                      'valuation_range_low': 115808},
#     'zpid': '1927741'}

# %%
api = zillow.ValuationApi()

address = "1554 Macarthur Dr, Boulder, CO"
postal_code = "80303"

#data = api.GetSearchResults(key, address, postal_code)
data = api.GetDeepSearchResults(key, address, postal_code)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(data.get_dict())

detail_data = api.GetZEstimate(key, data.zpid)

comp_data = api.GetComps(key, data.zpid)

#pp.pprint(comp_data['comps'][1].get_dict())
# Out:
# {   'extended_data': {   'bathrooms': '3.0',
#                          'bedrooms': '4',
#                          'complete': True,
#                          'finished_sqft': '1940',
#                          'fips_county': '8013',
#                          'last_sold_date': '07/29/1994',
#                          'last_sold_price': '169000',
#                          'lot_size_sqft': '1411',
#                          'tax_assessment': '488200.0',
#                          'tax_assessment_year': '2017',
#                          'usecode': 'Townhouse',
#                          'year_built': '1980'},
#     'full_address': {   'city': 'BOULDER',
#                         'latitude': '40.014109',
#                         'longitude': '-105.237108',
#                         'state': 'CO',
#                         'street': '1554 Macarthur Dr',
#                         'zipcode': '80303'},
#     'links': {   'comparables': 'http://www.zillow.com/homes/comps/13227741_zpid/',
#                  'graphs_and_data': 'http://www.zillow.com/homedetails/1554-Macarthur-Dr-Boulder-CO-80303/13227741_zpid/#charts-and-data',
#                  'home_details': 'https://www.zillow.com/homedetails/1554-Macarthur-Dr-Boulder-CO-80303/13227741_zpid/',
#                  'map_this_home': 'http://www.zillow.com/homes/13227741_zpid/'},
#     'local_realestate': {   'fsbo_link': 'http://www.zillow.com/east-foothills-boulder-co/fsbo/',
#                             'overview_link': 'http://www.zillow.com/local-info/CO-Boulder/East-Foothills/r_416067/',
#                             'region_id': '416067',
#                             'region_name': 'East Foothills',
#                             'region_type': 'neighborhood',
#                             'sale_link': 'http://www.zillow.com/east-foothills-boulder-co/',
#                             'zillow_home_value_index': None},
#     'similarity_score': None,
#     'zestimate': {   'amount': 568276,
#                      'amount_change_30days': -8022,
#                      'amount_currency': 'USD',
#                      'amount_last_updated': '07/10/2018',
#                      'valuation_range_high': 596690,
#                      'valuation_range_low': 539862},
#     'zpid': '13227741'}
